# %%
# importing pandas module 
import pandas as pd

# %%
df = pd.read_csv("2018.csv") 
  
#df["gender"].dropna("0") 
  
    
df[df["gender"] == 0].drop
df.head()
# Out:
#    Unnamed: 0  tripduration                 starttime  \
# 0           0          1635  2018-09-01 00:00:05.2690
# 1           1           132  2018-09-01 00:00:11.2810
# 2           2          3337  2018-09-01 00:00:20.6490
# 3           3           436  2018-09-01 00:00:21.7460
# 4           4          8457  2018-09-01 00:00:27.3150
#
#                    stoptime  start station id  \
# 0  2018-09-01 00:27:20.6340             252.0
# 1  2018-09-01 00:02:23.4810             314.0
# 2  2018-09-01 00:55:58.5470            3142.0
# 3  2018-09-01 00:07:38.5830             308.0
# 4  2018-09-01 02:21:25.3080             345.0
#
#                 start station name  start station latitude  \
# 0     MacDougal St & Washington Sq               40.732264
# 1  Cadman Plaza West & Montague St               40.693830
# 2                  1 Ave & E 62 St               40.761227
# 3          St James Pl & Oliver St               40.713079
# ...

# %%
# Drop via logic: similar to SQL 'WHERE' clause
newdf = df[df.gender != 0]
newdf.head()
# Out:
#    Unnamed: 0  tripduration                 starttime  \
# 0           0          1635  2018-09-01 00:00:05.2690
# 2           2          3337  2018-09-01 00:00:20.6490
# 3           3           436  2018-09-01 00:00:21.7460
# 4           4          8457  2018-09-01 00:00:27.3150
# 5           5          3326  2018-09-01 00:00:29.3030
#
#                    stoptime  start station id            start station name  \
# 0  2018-09-01 00:27:20.6340             252.0  MacDougal St & Washington Sq
# 2  2018-09-01 00:55:58.5470            3142.0               1 Ave & E 62 St
# 3  2018-09-01 00:07:38.5830             308.0       St James Pl & Oliver St
# 4  2018-09-01 02:21:25.3080             345.0               W 13 St & 6 Ave
# 5  2018-09-01 00:55:56.2020            3142.0               1 Ave & E 62 St
#
#    start station latitude  start station longitude  end station id  \
# 0               40.732264               -73.998522           366.0
# ...

# %%
newdf.count()
# Out:
# Unnamed: 0                 16063784
# tripduration               16063784
# starttime                  16063784
# stoptime                   16063784
# start station id           16061560
# start station name         16061560
# start station latitude     16063784
# start station longitude    16063784
# end station id             16061560
# end station name           16061560
# end station latitude       16063784
# end station longitude      16063784
# bikeid                     16063784
# usertype                   16063784
# birth year                 16063784
# gender                     16063784
# dtype: int64

# %%
lastdf = newdf[newdf.usertype != 'Customer']
lastdf.head()
# Out:
#    Unnamed: 0  tripduration                 starttime  \
# 0           0          1635  2018-09-01 00:00:05.2690
# 2           2          3337  2018-09-01 00:00:20.6490
# 3           3           436  2018-09-01 00:00:21.7460
# 5           5          3326  2018-09-01 00:00:29.3030
# 6           6           233  2018-09-01 00:00:27.2780
#
#                    stoptime  start station id            start station name  \
# 0  2018-09-01 00:27:20.6340             252.0  MacDougal St & Washington Sq
# 2  2018-09-01 00:55:58.5470            3142.0               1 Ave & E 62 St
# 3  2018-09-01 00:07:38.5830             308.0       St James Pl & Oliver St
# 5  2018-09-01 00:55:56.2020            3142.0               1 Ave & E 62 St
# 6  2018-09-01 00:04:20.7420            3526.0                31 St & 23 Ave
#
#    start station latitude  start station longitude  end station id  \
# 0               40.732264               -73.998522           366.0
# ...

# %%
lastdf.count()
# Out:
# Unnamed: 0                 15309741
# tripduration               15309741
# starttime                  15309741
# stoptime                   15309741
# start station id           15308533
# start station name         15308533
# start station latitude     15309741
# start station longitude    15309741
# end station id             15308533
# end station name           15308533
# end station latitude       15309741
# end station longitude      15309741
# bikeid                     15309741
# usertype                   15309741
# birth year                 15309741
# gender                     15309741
# dtype: int64

# %%
df1 = lastdf[lastdf['birth year'] > 1959]
df1.head()
# Out:
#    Unnamed: 0  tripduration                 starttime  \
# 0           0          1635  2018-09-01 00:00:05.2690
# 2           2          3337  2018-09-01 00:00:20.6490
# 3           3           436  2018-09-01 00:00:21.7460
# 5           5          3326  2018-09-01 00:00:29.3030
# 6           6           233  2018-09-01 00:00:27.2780
#
#                    stoptime  start station id            start station name  \
# 0  2018-09-01 00:27:20.6340             252.0  MacDougal St & Washington Sq
# 2  2018-09-01 00:55:58.5470            3142.0               1 Ave & E 62 St
# 3  2018-09-01 00:07:38.5830             308.0       St James Pl & Oliver St
# 5  2018-09-01 00:55:56.2020            3142.0               1 Ave & E 62 St
# 6  2018-09-01 00:04:20.7420            3526.0                31 St & 23 Ave
#
#    start station latitude  start station longitude  end station id  \
# 0               40.732264               -73.998522           366.0
# ...

# %%
df1.count()
# Out:
# Unnamed: 0                 14226447
# tripduration               14226447
# starttime                  14226447
# stoptime                   14226447
# start station id           14225305
# start station name         14225305
# start station latitude     14226447
# start station longitude    14226447
# end station id             14225305
# end station name           14225305
# end station latitude       14226447
# end station longitude      14226447
# bikeid                     14226447
# usertype                   14226447
# birth year                 14226447
# gender                     14226447
# dtype: int64

# %%
df1.to_csv('2018v2.csv')
